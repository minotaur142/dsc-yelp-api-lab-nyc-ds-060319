# %% [markdown]
# # Yelp API - Lab
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works and some basic Folium visualizations, it's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Perform pagination to retrieve troves of data!
# * Create a simple geographical system on to view information about selected businesses, at a given location.
#
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you, but make the request below.

# %%
#Your code here
import requests
api_key = "MZZqWmVc6ZJAuPd7FKHcwnxgjGxaQyQMMVcN5af3PZetVhoGrmTWQWwEIrRVuegzuC2EL7T8CJvDQCqJ8Ga1CZkaM7jisfvp3r8ME_BdyvzvTu6mXfjO-vhUWjASXXYx"
term = 'Jamaican'
location = 'Harlem NY'
SEARCH_LIMIT = 50

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
import json
dic = json.loads(response.text)

# %%
dic['businesses']
# Out:
# [{'id': 'kEswi0_V_bhJJwTCspOwxg',
#   'alias': 'caribbean-starr-restaurant-new-york',
#   'name': 'Caribbean Starr Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/39fHjsmqJWeQ4nNm1vCxzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caribbean-starr-restaurant-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 61,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8071360749804,
#    'longitude': -73.9456482098171},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '280 Malcolm X Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['280 Malcolm X Blvd', 'New York, NY 10027']},
#   'phone': '+19172617668',
#   'display_phone': '(917) 261-7668',
#   'distance': 1070.832927674334},
#  {'id': 'kdofxNdF_5Hcmhs5EgX8Zw',
#   'alias': 'wats-on-your-plate-new-york-2',
#   'name': "Wat's On Your Plate",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ag11z030xTXDvIWl2utvyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wats-on-your-plate-new-york-2?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 56,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8258666992188,
#    'longitude': -73.9483795166016},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '513 W 145th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10031',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['513 W 145th St', 'New York, NY 10031']},
#   'phone': '+12122344411',
#   'display_phone': '(212) 234-4411',
#   'distance': 1063.8449279392917},
#  {'id': 'pGAuqQTD7UnPi4AhlPMHsA',
#   'alias': 'jerkyz-new-york',
#   'name': 'Jerkyz',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6lorLx9yopnEFa171HaDww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jerkyz-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 99,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.818443, 'longitude': -73.941917},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '2394 Adam Clayton Powell Jr Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10030',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2394 Adam Clayton Powell Jr Blvd',
#     'New York, NY 10030']},
#   'phone': '+12128372484',
#   'display_phone': '(212) 837-2484',
#   'distance': 694.7391150881213},
#  {'id': 'naI718vRrMwqr42Ar90TgQ',
#   'alias': 'king-barka-new-york',
#   'name': 'King Barka',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s5yTr1bhygG1zOzkmJM1QA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/king-barka-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 34,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.8167957956894,
#    'longitude': -73.9468355476856},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '301 W 135th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10030',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['301 W 135th St', 'New York, NY 10030']},
#   'phone': '+16469520394',
#   'display_phone': '(646) 952-0394',
#   'distance': 244.746761077491},
#  {'id': 'BQcgpQxUM39PMO_YDl_CqA',
#   'alias': 'fredas-caribbean-and-soul-cuisine-new-york',
#   'name': "Freda's Caribbean & Soul Cuisine",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4JLFuFJ2kpnpMHO7ZSqvyQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fredas-caribbean-and-soul-cuisine-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 516,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.80095, 'longitude': -73.96141},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '993 Columbus Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['993 Columbus Ave', 'New York, NY 10025']},
#   'phone': '+16464389832',
#   'display_phone': '(646) 438-9832',
#   'distance': 1970.207749858209},
#  {'id': 'CjUMkpPprcw-PuJ7gZEtTw',
#   'alias': 'kingston-harlem',
#   'name': 'Kingston',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_kmC0NsOkynVpV_utPmPrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kingston-harlem?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 111,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.8033638000488,
#    'longitude': -73.9535980224609},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '218 W 116th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Harlem',
#    'zip_code': '10026',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['218 W 116th St', 'Harlem, NY 10026']},
#   'phone': '+16468611082',
#   'display_phone': '(646) 861-1082',
#   'distance': 1473.2266862401273},
#  {'id': 'H4fS32597GN025rMM85W-g',
#   'alias': 'sisters-caribbean-cuisine-new-york',
#   'name': "Sisters' Caribbean Cuisine",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/s2onSwYdrYJ8-9duIZYgrA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sisters-caribbean-cuisine-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 145,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.80503, 'longitude': -73.94082},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '47 E 124th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10035',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['47 E 124th St', 'New York, NY 10035']},
#   'phone': '+12124103000',
#   'display_phone': '(212) 410-3000',
#   'distance': 1458.0936807234812},
#  {'id': '4QPKfSfhLRomEEM5160Fzg',
#   'alias': 'freddys-soul-caribbean-restaurant-new-york',
#   'name': "Freddy's Soul Caribbean Restaurant",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UK_ZvD5-sTxZYwBJT_sBQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/freddys-soul-caribbean-restaurant-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 27,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.8055, 'longitude': -73.9513599},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1980 Adam Clayton Powell Jr Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10026',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1980 Adam Clayton Powell Jr Blvd',
#     'New York, NY 10026']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1216.6871713561768},
#  {'id': 'atwSgQ1RS1XSr9Hwd3SZdQ',
#   'alias': 'little-ochie-jamaican-cuisine-new-york',
#   'name': 'Little Ochie Jamaican Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xp8hufWE59oNta1Sxe_fUQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-ochie-jamaican-cuisine-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 42,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.82153, 'longitude': -73.93965},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2492 Adam Clayton Powell Jr Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10030',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2492 Adam Clayton Powell Jr Blvd',
#     'New York, NY 10030']},
#   'phone': '+12122346300',
#   'display_phone': '(212) 234-6300',
#   'distance': 1032.3096484875482},
#  {'id': 'iHiEMvbpLzNYTMsd5-VnQw',
#   'alias': 'jacob-soul-food-restaurant-new-york-2',
#   'name': 'Jacob Soul Food Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2FRw5PI8DHPTvnF3Op7lLA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacob-soul-food-restaurant-new-york-2?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 322,
#   'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.810025, 'longitude': -73.9439219},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '373 Lenox Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['373 Lenox Ave', 'New York, NY 10027']},
#   'phone': '+12128663663',
#   'display_phone': '(212) 866-3663',
#   'distance': 846.3129706265985},
#  {'id': '9eywZbpli6h_zOawIT8E7w',
#   'alias': 'one-stop-patty-shop-new-york',
#   'name': 'One Stop Patty Shop',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oef7YWfXC-AMsgTHw1Fw1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/one-stop-patty-shop-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 36,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.82498, 'longitude': -73.94802},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1708 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10031',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1708 Amsterdam Ave', 'New York, NY 10031']},
#   'phone': '+12124917466',
#   'display_phone': '(212) 491-7466',
#   'distance': 981.3902896919923},
#  {'id': 'ueVSTErmXbqtN1glQd5p5A',
#   'alias': 'greedy-pot-new-york',
#   'name': 'Greedy Pot',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Tt1dWRZSxK6ZGisZGCBPlQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/greedy-pot-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 13,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.80417, 'longitude': -73.95216},
#   'transactions': ['delivery'],
#   'location': {'address1': '1944 7th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10026',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1944 7th Ave', 'New York, NY 10026']},
#   'phone': '+19176757676',
#   'display_phone': '(917) 675-7676',
#   'distance': 1362.018508917278},
#  {'id': 'FA5DaDQyH9tGDyXE_UUbRw',
#   'alias': 'lynx-kitchen-new-york-2',
#   'name': 'Lynx Kitchen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bhvE5nJ26JARoiNN3xAkYw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lynx-kitchen-new-york-2?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 16,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.8143185409025,
#    'longitude': -73.9370122320218},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1 W 137th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10037',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 W 137th St', 'New York, NY 10037']},
#   'phone': '+16468526400',
#   'display_phone': '(646) 852-6400',
#   'distance': 1086.4708353447875},
#  {'id': 'phuM6HvtRNleK7gkRM0-UQ',
#   'alias': 'hot-pot-under-de-tree-new-york',
#   'name': 'Hot Pot Under De Tree',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h4bO31S-3xbnJINcW0_fAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hot-pot-under-de-tree-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 23,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.826965, 'longitude': -73.93927},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2839 Frederick Douglas Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10039',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2839 Frederick Douglas Blvd', 'New York, NY 10039']},
#   'phone': '+12122343505',
#   'display_phone': '(212) 234-3505',
#   'distance': 1475.6918801156673},
#  {'id': 'vsqp_lTJxqvqRXWwCHXy_A',
#   'alias': 'rustys-flavor-new-york',
#   'name': "Rusty's Flavor",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GNUIdSbDmiNyGHQr6bftkA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rustys-flavor-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 34,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.81356, 'longitude': -73.94445},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2253 Adam Clayton Powell Jr Blvd',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2253 Adam Clayton Powell Jr Blvd',
#     'New York, NY 10027']},
#   'phone': '+12123683403',
#   'display_phone': '(212) 368-3403',
#   'distance': 528.3527118472036},
#  {'id': 'Xd4Ahhb1alLxBapbcTl4Nw',
#   'alias': 'blue-mountain-heights-cafe-and-bar-new-york',
#   'name': 'Blue Mountain Heights Cafe & Bar',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GLMRpVVjUrAtLbt408nO8Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-mountain-heights-cafe-and-bar-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 41,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.83346, 'longitude': -73.94116},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '499 W 158th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10032',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['499 W 158th St', 'New York, NY 10032']},
#   'phone': '+16469985905',
#   'display_phone': '(646) 998-5905',
#   'distance': 2044.9218280384623},
#  {'id': 'rOc8TqQEqBLlxgYOPsgRUQ',
#   'alias': 'peoples-choice-kitchen-new-york',
#   'name': "People's Choice Kitchen",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3hzgOSsiTccU-7Uf9YInkg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/peoples-choice-kitchen-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 45,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.823394, 'longitude': -73.94194},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2733 Frederick Douglass B',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10039',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2733 Frederick Douglass B', 'New York, NY 10039']},
#   'phone': '+12122813830',
#   'display_phone': '(212) 281-3830',
#   'distance': 1027.5525455529387},
#  {'id': 'X0QdRUQC1vhVBRv7kOU35g',
#   'alias': 'baraka-buffet-restaurant-manhattan',
#   'name': 'Baraka Buffet Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ZlZiozKPgeppACiIAKpN4A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/baraka-buffet-restaurant-manhattan?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 9,
#   'categories': [{'alias': 'african', 'title': 'African'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.81688, 'longitude': -73.94605},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2546 Frederick Douglass Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Manhattan',
#    'zip_code': '10039',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2546 Frederick Douglass Blvd', 'Manhattan, NY 10039']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 320.86526841467037},
#  {'id': 'InPXqXSyvxP2yL_F1VU-Mg',
#   'alias': 'smokey-island-grille-bronx',
#   'name': 'Smokey island Grille',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4ddNww4nH408OH1gDsvguw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/smokey-island-grille-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 23,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8256002740113,
#    'longitude': -73.9191630846558},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '260 E 161st St',
#    'address2': '',
#    'address3': None,
#    'city': 'Bronx',
#    'zip_code': '10451',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['260 E 161st St', 'Bronx, NY 10451']},
#   'phone': '+17186841475',
#   'display_phone': '(718) 684-1475',
#   'distance': 2767.91568614434},
#  {'id': '5laPr-K_L1MDJYO3x4VHNQ',
#   'alias': 'flavas-international-grill-bronx-2',
#   'name': 'Flavas International Grill',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jZP1BWqQzq3b8-ginXsLUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flavas-international-grill-bronx-2?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 107,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.82704, 'longitude': -73.92511},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '854 Gerard Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Bronx',
#    'zip_code': '10451',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['854 Gerard Ave', 'Bronx, NY 10451']},
#   'phone': '+17182922900',
#   'display_phone': '(718) 292-2900',
#   'distance': 2395.6167353997594},
#  {'id': 'tsiC3VpO-hZEb98Qk3p-DQ',
#   'alias': 'amy-ruths-new-york',
#   'name': "Amy Ruth's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aX-TMDOSS2vO-0L47FoZ0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amy-ruths-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 2458,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.80248, 'longitude': -73.95038},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '113 W 116th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10026',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['113 W 116th St', 'New York, NY 10026']},
#   'phone': '+12122808779',
#   'display_phone': '(212) 280-8779',
#   'distance': 1526.5466259542486},
#  {'id': 'mLmmN7oLye5SzjfpGD7eLA',
#   'alias': 'solomon-and-kuff-new-york',
#   'name': 'Solomon and Kuff',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y9wUhVIStgpEk0XgdcW0JQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/solomon-and-kuff-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 358,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.82005, 'longitude': -73.9586099},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2331 12th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2331 12th Ave', 'New York, NY 10027']},
#   'phone': '+12122831819',
#   'display_phone': '(212) 283-1819',
#   'distance': 857.9108301683583},
#  {'id': 's9ZnveHKnRF89mH9vG-Ylw',
#   'alias': 'bickles-2-go-bronx-4',
#   'name': 'Bickles 2 Go',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3wTOFg6Ilg41x4w9GH-Omg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bickles-2-go-bronx-4?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 19,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.81902, 'longitude': -73.91855},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '647 Courtlandt Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10451',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['647 Courtlandt Ave', 'Bronx, NY 10451']},
#   'phone': '+13479634184',
#   'display_phone': '(347) 963-4184',
#   'distance': 2634.593483700766},
#  {'id': 'kwMkNIhhIexQk-nmloJlnw',
#   'alias': 'angel-of-harlem-new-york',
#   'name': 'Angel of Harlem',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xXaLWZ9LX6hjBhXyt-A78Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/angel-of-harlem-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 429,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.807978, 'longitude': -73.952365},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2272 Frederick Douglass Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2272 Frederick Douglass Blvd', 'New York, NY 10027']},
#   'phone': '+12123160350',
#   'display_phone': '(212) 316-0350',
#   'distance': 942.5947060838006},
#  {'id': 'bxJh48jROb-KKy9rPUrHjQ',
#   'alias': 'eating-tree-bronx',
#   'name': 'Eating Tree',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TuRVOqDcpGZngP0g245_Vg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/eating-tree-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 118,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8281599, 'longitude': -73.92442},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '892 Gerard Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10452',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['892 Gerard Ave', 'Bronx, NY 10452']},
#   'phone': '+17182935025',
#   'display_phone': '(718) 293-5025',
#   'distance': 2503.952495511917},
#  {'id': '3yWhGyaQsiav0Q29yxbsMA',
#   'alias': 'fauzias-heavenly-delights-bronx',
#   'name': "Fauzia's Heavenly Delights",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3LjjI_dGXZc_OV4buLKZg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fauzias-heavenly-delights-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 33,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'foodstands', 'title': 'Food Stands'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.8264, 'longitude': -73.92115},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '161st St & Sheridan Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10451',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['161st St & Sheridan Ave', 'Bronx, NY 10451']},
#   'phone': '+17189305711',
#   'display_phone': '(718) 930-5711',
#   'distance': 2648.8345092152986},
#  {'id': 'ONkwCKmCSlzk3Jmaf9vqcA',
#   'alias': 'mamas-restaurant-new-york',
#   'name': "Mama's Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VgB_uDFmxJxN5OWupdepEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mamas-restaurant-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 52,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.799931, 'longitude': -73.936081},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2347 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10035',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2347 2nd Ave', 'New York, NY 10035']},
#   'phone': '+12124104210',
#   'display_phone': '(212) 410-4210',
#   'distance': 2147.2513691873373},
#  {'id': 'fkJ4Nr8xs3xjgl9T7d6Agw',
#   'alias': 'corner-style-jamaican-and-american-bronx',
#   'name': 'Corner Style Jamaican & American',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PMf1w6gO5mJKL3zg7IlUEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/corner-style-jamaican-and-american-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 36,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.83489, 'longitude': -73.91971},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1195 Walton Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10452',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1195 Walton Ave', 'Bronx, NY 10452']},
#   'phone': '+17184108460',
#   'display_phone': '(718) 410-8460',
#   'distance': 3251.7303015976427},
#  {'id': 'zuaO8_t7NWCWP7ewuuuTBg',
#   'alias': 't-and-j-jamaican-flava-new-york',
#   'name': 'T & J Jamaican Flava',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W17dvZ6bYkFek7slo8zE7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/t-and-j-jamaican-flava-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 16,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.78723, 'longitude': -73.95156},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1257 Park Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10029',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1257 Park Ave', 'New York, NY 10029']},
#   'phone': '+12128608603',
#   'display_phone': '(212) 860-8603',
#   'distance': 3234.224656529773},
#  {'id': 'd_CMJNAxEsYtrdtb7R4NRA',
#   'alias': 'caribbean-hut-west-bronx',
#   'name': 'Caribbean Hut',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c7BPHu3KAajFDydhl4fYkg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caribbean-hut-west-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 17,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.8182379159255,
#    'longitude': -73.9150771122443},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '651 Elton Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'West Bronx',
#    'zip_code': '10451',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['651 Elton Ave', 'West Bronx, NY 10451']},
#   'phone': '+13475909557',
#   'display_phone': '(347) 590-9557',
#   'distance': 2918.500642036773},
#  {'id': 'rMhPj7Avw46g0nnyTiNKNg',
#   'alias': 'island-bites-new-york-2',
#   'name': 'Island Bites',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eo1LHn3C-iIvt-QJKGV2bQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/island-bites-new-york-2?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 12,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.79117, 'longitude': -73.93916},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '2107 1st Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10029',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2107 1st Ave', 'New York, NY 10029']},
#   'phone': '+16468508855',
#   'display_phone': '(646) 850-8855',
#   'distance': 2928.092365521554},
#  {'id': 'L3xP3WAu_oB1-yMoKc1i9w',
#   'alias': 'golden-krust-bakery-new-york',
#   'name': 'Golden Krust Bakery',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mIBJi1w2UmHz3HZZqJVFEg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/golden-krust-bakery-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 22,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.8080965, 'longitude': -73.9459085},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '121 W 125th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['121 W 125th St', 'New York, NY 10027']},
#   'phone': '+12126637451',
#   'display_phone': '(212) 663-7451',
#   'distance': 894.6559458506233},
#  {'id': 'kFxtbYKHvIiez-O12Kdblw',
#   'alias': 'flavas-restaurant-and-lounge-bronx',
#   'name': "Flava's Restaurant & Lounge",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/23WzmtFYZKF1bZMd8zlkgw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flavas-restaurant-and-lounge-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 9,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.8218447356858,
#    'longitude': -73.9116299074709},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '3114 Third Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Bronx',
#    'zip_code': '10451',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3114 Third Ave', 'Bronx, NY 10451']},
#   'phone': '+13473528218',
#   'display_phone': '(347) 352-8218',
#   'distance': 3259.707293128881},
#  {'id': 'XJ8mq5IE2LQ0AYq574KAIw',
#   'alias': 'rebeccas-restaurant-edgewater-2',
#   'name': "Rebecca's Restaurant",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/H6iv9tQjbbzq80c-J-HRtg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rebeccas-restaurant-edgewater-2?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 258,
#   'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#    {'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8090199, 'longitude': -73.99101},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '236 Old River Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Edgewater',
#    'zip_code': '07020',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['236 Old River Rd', 'Edgewater, NJ 07020']},
#   'phone': '+12019438808',
#   'display_phone': '(201) 943-8808',
#   'distance': 3567.405629827023},
#  {'id': '5zbm-v588DGgpce2MjG_5A',
#   'alias': 'jacob-restaurant-new-york-4',
#   'name': 'Jacob Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6bDvYCInucwLCIrtpL9i3Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacob-restaurant-new-york-4?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 85,
#   'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8218073, 'longitude': -73.9429281},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2695 Frederick Douglass Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10030',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2695 Frederick Douglass Blvd', 'New York, NY 10030']},
#   'phone': '+12122833663',
#   'display_phone': '(212) 283-3663',
#   'distance': 836.3499404982525},
#  {'id': 't5-7acjxbd5aNAR5oYi-9w',
#   'alias': 'harlem-karibe-restaurant-and-catering-new-york',
#   'name': 'Harlem Karibe Restaurant & Catering',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W79GamfKHlgQZJfDR0QJkw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/harlem-karibe-restaurant-and-catering-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 65,
#   'categories': [{'alias': 'haitian', 'title': 'Haitian'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.8133004, 'longitude': -73.9456163},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2234 Adam Clayton Powell Jr Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2234 Adam Clayton Powell Jr Blvd',
#     'New York, NY 10027']},
#   'phone': '+18452109022',
#   'display_phone': '(845) 210-9022',
#   'distance': 474.6178918786977},
#  {'id': 'Z-hDHjP4Eza6BA4G97tzVA',
#   'alias': 'blvd-bistro-new-york',
#   'name': 'BLVD Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lML0a7MlD13TSsKjD-V_pQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blvd-bistro-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 698,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8043626, 'longitude': -73.9557515},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2149 Frederick Douglass Blvd',
#    'address2': 'Corner of 116th',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10026',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2149 Frederick Douglass Blvd',
#     'Corner of 116th',
#     'New York, NY 10026']},
#   'phone': '+12126786200',
#   'display_phone': '(212) 678-6200',
#   'distance': 1420.2871320862803},
#  {'id': 'DgpnbYHVKWVuy_MC_5iiJA',
#   'alias': 'la-savane-new-york',
#   'name': 'La Savane',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mVb_BLRYB7CUHgcA0_ZW4A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-savane-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 73,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8042488098145, 'longitude': -73.954216003418},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '239 W 116th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10026',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['239 W 116th St', 'New York, NY 10026']},
#   'phone': '+16464904644',
#   'display_phone': '(646) 490-4644',
#   'distance': 1394.1959547772528},
#  {'id': 'A_VOUhoL1JBor4e2UbaaPQ',
#   'alias': 'island-spice-grill-new-york',
#   'name': 'Island Spice Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/peG_RYn5j3QLmAeEBew9nQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/island-spice-grill-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 48,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7378, 'longitude': -73.99012},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '18th St & Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10004',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['18th St & Broadway', 'New York, NY 10004']},
#   'phone': '+17185014600',
#   'display_phone': '(718) 501-4600',
#   'distance': 9367.593672424835},
#  {'id': 'vBGRIvltp5KAeiAfjwDPpg',
#   'alias': 'el-valle-restaurant-new-york-20',
#   'name': 'El Valle Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UthVK3z45DjhJEnL5PpTCQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-valle-restaurant-new-york-20?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 19,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.81699, 'longitude': -73.93842},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '588 Lenox Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10037',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['588 Lenox Ave', 'New York, NY 10037']},
#   'phone': '+16463441475',
#   'display_phone': '(646) 344-1475',
#   'distance': 930.5049298585773},
#  {'id': 'Ajwv2EBfIhtioKDdbYQF2A',
#   'alias': 'kaylahs-hut-bronx',
#   'name': "Kaylah's Hut",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/157seUzzWXCDwb_1WGgr5Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kaylahs-hut-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 20,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.81926, 'longitude': -73.90201},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '805 Prospect Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10455',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['805 Prospect Ave', 'Bronx, NY 10455']},
#   'phone': '+17184508252',
#   'display_phone': '(718) 450-8252',
#   'distance': 4017.831187658195},
#  {'id': 'vS7Cah19CwvrIn2G9iK4lg',
#   'alias': 'golden-crust-new-york',
#   'name': 'Golden Crust',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ns8jjmT-oDW5XYYbUOK5mA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/golden-crust-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 5,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.8043813, 'longitude': -73.9374062},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': 'Lexington Ave & 125th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10035',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['Lexington Ave & 125th St', 'New York, NY 10035']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1677.131504078777},
#  {'id': 'IO6QAXCXu_31YZBeXGclcQ',
#   'alias': 'mannas-soul-food-restaurant-new-york-3',
#   'name': "Manna's Soul Food Restaurant",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OUCyKA0ml2jqgAHz9Qk6Eg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mannas-soul-food-restaurant-new-york-3?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 79,
#   'categories': [{'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'buffets', 'title': 'Buffets'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.81338, 'longitude': -73.94105},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '486 Malcolm X Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10037',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['486 Malcolm X Blvd', 'New York, NY 10037']},
#   'phone': '+12122344488',
#   'display_phone': '(212) 234-4488',
#   'distance': 803.849626409981},
#  {'id': 'QuWIq9ZvULkLQFpZh03eLA',
#   'alias': 'bognan-international-west-african-restaurant-bronx',
#   'name': 'Bognan International West African Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/J49KI-AhvSUtTNyMByR-2g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bognan-international-west-african-restaurant-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 21,
#   'categories': [{'alias': 'african', 'title': 'African'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8318596, 'longitude': -73.9026031},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '590 E 169th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10456',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['590 E 169th St', 'Bronx, NY 10456']},
#   'phone': '+13472715457',
#   'display_phone': '(347) 271-5457',
#   'distance': 4319.883050288075},
#  {'id': 'hw8ziubXsFocun6KR04VVg',
#   'alias': 'malecon-restaurant-new-york-2',
#   'name': 'Malecon Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0imNctPMuYnAe9jUhlPFGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/malecon-restaurant-new-york-2?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 659,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'dominican', 'title': 'Dominican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.84651, 'longitude': -73.93882},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '4141 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10033',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4141 Broadway', 'New York, NY 10033']},
#   'phone': '+12129273812',
#   'display_phone': '(212) 927-3812',
#   'distance': 3476.412174515747},
#  {'id': 'ArbdHUoVz9vnLSB7gRiMAA',
#   'alias': 'o-bs-bakery-jamaica-2',
#   'name': "O.B's Bakery",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GY_GXhn9OTcq1GXH69jc0g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/o-bs-bakery-jamaica-2?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 27,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.6793797, 'longitude': -73.7775943},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '16576 Baisley Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Jamaica',
#    'zip_code': '11434',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['16576 Baisley Blvd', 'Jamaica, NY 11434']},
#   'phone': '+17189784247',
#   'display_phone': '(718) 978-4247',
#   'distance': 21151.333253238314},
#  {'id': 'RI-tVET-wKFeRNKm4cg0wQ',
#   'alias': 'sylvias-restaurant-new-york',
#   'name': "Sylvia's Restaurant",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LNlBq8ut6HOl4jqpZGrUsw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sylvias-restaurant-new-york?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 1702,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.808609, 'longitude': -73.944404},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '328 Malcolm X Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['328 Malcolm X Blvd', 'New York, NY 10027']},
#   'phone': '+12129960660',
#   'display_phone': '(212) 996-0660',
#   'distance': 958.4835341491641},
#  {'id': 'P9IG9-__KT2NqnwzStkheg',
#   'alias': 'back-home-2-bronx',
#   'name': 'Back Home 2',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TgZVFbPivhSRGGYFXFjcNw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/back-home-2-bronx?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 23,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.8308899, 'longitude': -73.9001},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '750 E 169th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10456',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['750 E 169th St', 'Bronx, NY 10456']},
#   'phone': '+17185899851',
#   'display_phone': '(718) 589-9851',
#   'distance': 4474.185070422139},
#  {'id': '8c3UnmA-8Qg3WYVRQDi2Wg',
#   'alias': 'lighthouse-fish-market-and-restaurant-new-york-6',
#   'name': 'Lighthouse Fish Market & Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kWYtSOxiTAG5lf7h5lS0zg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lighthouse-fish-market-and-restaurant-new-york-6?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 195,
#   'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.81434, 'longitude': -73.94854},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2451 Frederick Douglass Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2451 Frederick Douglass Blvd', 'New York, NY 10027']},
#   'phone': '+12122032241',
#   'display_phone': '(212) 203-2241',
#   'distance': 247.1226103158764},
#  {'id': 'Jzig-SlvalqSpffF39nYjw',
#   'alias': 'golden-krust-bronx-9',
#   'name': 'Golden Krust',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dsU6A1xaB_4DBgCuPOMmCw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/golden-krust-bronx-9?adjust_creative=lAC08S22YU_r9SEhNquHLw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lAC08S22YU_r9SEhNquHLw',
#   'review_count': 4,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.8314028, 'longitude': -73.9001079},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1299 Boston Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10456',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1299 Boston Rd', 'Bronx, NY 10456']},
#   'phone': '+17183781133',
#   'display_phone': '(718) 378-1133',
#   'distance': 4491.3021554622765}]

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
# Your code here; use a function or loop to retrieve all the results from your original request
dic['businesses']
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-d9ed75e63c9e> in <module>()
#       1 # Your code here; use a function or loop to retrieve all the results from your original request
# ----> 2 dic['businesses']
#
# NameError: name 'dic' is not defined

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an initial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
#Your code here
# import pandas as pd
# df = pd.DataFrame.from_dict(dic['businesses'])

# df.price = df.price.str.len()
# df.categories = [i[0]['title']for i in df.categories]
df.categories.value_counts()
df.loc[:,['price','rating']].corr()
# Out:
#            price    rating
# price   1.000000  0.034651
# rating  0.034651  1.000000

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
#Your code here
import folium

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you synthesized your skills for the day, making multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice map visual to display the results! Well done!
